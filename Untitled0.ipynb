# %% [markdown]
# <a href="https://colab.research.google.com/github/bassemmarji/FaceAnalyzer/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# ...

# %%
import tweepy
tweepy.__version__
# Out:
# '3.10.0'

# %%
import tweepy

# Authenticate to Twitter
auth = tweepy.OAuthHandler(
           consumer_key= "pGBDoAaEpkliVKBOLwjtcmHGc"
         , consumer_secret="xF3g1wrP50b6BlZEd20u4oVfjgH1FGQcuWUzlQO5aUWOufvlhw")

auth.set_access_token(
           "622518493-6VcLIPprbQbv9wkcBBPvCle8vsjU9fE85Dq9oStl"
         , "tH9aKQbQQ1iRdYTcLSsPwitl44BkAc6jilrsU0ifnXvZhq")


# wait_on_rate_limit and wait_on_rate_limit_notify 
# print a message and wait if the rate limit is exceeded
api = tweepy.API(auth,wait_on_rate_limit=True
                     ,wait_on_rate_limit_notify=True)

userName = '@BarackObama'
user = api.get_user(userName)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")


#Print the author and text of the last tweet in the timeline
timeline = api.home_timeline()
for tweet in timeline:
      print(f"{tweet.user.name} said {tweet.text}")
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-16-c06936c07c77> in <module>()
#      17
#      18 userName = '@BarackObama'
# ---> 19 user = api.get_user(userName)
#      20
#      21 try:
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# /usr/local/lib/python3.7/dist-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: [{'code': 89, 'message': 'Invalid or expired token.'}]
